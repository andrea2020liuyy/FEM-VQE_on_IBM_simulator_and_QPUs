# %%
# Import Packages

import sys
import random
import scipy
import scipy.sparse as sparse
from scipy.sparse import coo_matrix
import numpy as np
from numpy import linalg as la
from numpy import sqrt, cos, sin
from math import pi, exp
import pandas as pd
from pandas import DataFrame

import csv
import gc
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor
import os
from os import getpid
import warnings
import time
import copy

from qiskit import *
from qiskit.circuit.library.n_local import TwoLocal
from qiskit.circuit.library import EfficientSU2
from qiskit.circuit.random import random_circuit
from qiskit.opflow import (Z, I, H, CircuitStateFn, StateFn)
from qiskit.opflow import MatrixOp
import shutil
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, transpile
from qiskit import BasicAer, Aer, transpile, assemble, execute
from qiskit.providers.aer import Aer
from qiskit.quantum_info import SparsePauliOp # USE quantum_info instead of opflow
from qiskit.quantum_info.operators import Operator
from qiskit.extensions import UnitaryGate
from scipy.optimize import minimize
import scipy.optimize as opt

from qiskit.algorithms import NumPyEigensolver
from qiskit import Aer  # change this to Aer for C++ compiled code and the option to run on the GPU
from qiskit.providers.aer import AerSimulator
from qiskit.algorithms import VQE
from qiskit.algorithms.minimum_eigensolvers import NumPyMinimumEigensolver
from qiskit.utils import algorithm_globals, QuantumInstance
import qiskit.quantum_info as qi
from qiskit.algorithms.optimizers import SLSQP, COBYLA, SPSA, L_BFGS_B
from qiskit.quantum_info import state_fidelity, Statevector, random_statevector, DensityMatrix
from qiskit.tools.visualization import circuit_drawer, plot_histogram, plot_state_city
from qiskit.ignis.mitigation.measurement import complete_meas_cal, CompleteMeasFitter
from qiskit.visualization import plot_histogram, plot_distribution, plot_state_hinton
from qiskit.visualization import plot_bloch_multivector, plot_state_qsphere
from qiskit.visualization import array_to_latex

# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
import pylab
import matplotlib.font_manager as fm
from matplotlib.ticker import EngFormatter
