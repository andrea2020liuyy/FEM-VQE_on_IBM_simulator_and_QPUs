# %%
# Import packages

import sys
import random
import scipy

import numpy as np
from numpy import linalg as la
from numpy import sqrt, cos, sin
from math import pi, exp
import pandas as pd
from pandas import DataFrame

import os
from os import getpid
import warnings
import time
import datetime
import copy

from qiskit import *
from qiskit.circuit.library.n_local import TwoLocal
from qiskit.circuit.library import EfficientSU2
from qiskit.circuit.random import random_circuit
from qiskit.opflow import (Z, I, X, Y, H, CircuitStateFn, StateFn)
from qiskit.opflow import MatrixOp
import shutil
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, transpile
from qiskit import BasicAer, transpile, assemble, execute
from qiskit.providers.aer import Aer, AerSimulator
from qiskit.quantum_info import SparsePauliOp, Pauli # USE quantum_info instead of opflow
from qiskit.quantum_info.operators import Operator

from scipy.optimize import minimize
import scipy.optimize as opt

from qiskit.algorithms import NumPyEigensolver
from qiskit import Aer  # change this to Aer for C++ compiled code and the option to run on the GPU
from qiskit.algorithms import VQE
from qiskit.utils import algorithm_globals, QuantumInstance

from qiskit.algorithms.optimizers import SLSQP, COBYLA, SPSA, L_BFGS_B

import qiskit.tools.jupyter
import qiskit_ibm_runtime
# qiskit_ibm_runtime.version.get_version_info()
from qiskit_ibm_runtime import Estimator, Session, QiskitRuntimeService, Options

# %config InlineBackend.figure_format = 'svg'
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab
